# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
# Upload the college_1.csv in files section & copy its path 
# Paste the path inside ('--here--')
# whenever u run google colab its necessary to check .csv file is uploaded

# %%
df_1 = pd.read_csv('/content/college_1.csv')
df_1

# we are taking college_1.csv file and assigning in dataframe --> "df_1"
# college_1.csv --> Holds 84 student details
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
# Upload the college_2.csv in files section & copy its path 
# Paste the path inside ('--here--')

# %%
df_2 = pd.read_csv('/content/college_2.csv')
df_2

# we are taking college_2.csv file and assigning in dataframe ---> "df_2"
# college_2.csv ---> holds 35 student details
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df = [df_1 , df_2]
df = pd.concat(df, ignore_index = True)
df

# Here merging(Concatinating) of both csv file[df_1 , df_2] in single dataframe --> df
# "ignore index = True" ---> Arranges & display index in numeric order 
# Memo:-
# df_1 consist of college_1.csv  (84-records)
# df_2 consist of college_2.csv  (35-records)
# df ---> df_1 + df_2 ---> 84 + 35 ==> 119
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
df.to_csv('combination of college_1 & college_2.csv')

# Combination/concatination of two csv files[df_1 and df_2] were stored in new _CSV file_ format ----named as----> "combination of college_1 & college_2.csv" 
# combination of college_1 & college_2.csv ---> holds 119 student details (college_1 + college_2 = 119)

# %%
df.info()

# displays all column information & datatype & count of non-null & index inside df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 8.5+ KB

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
a = df[(df["CodeKata Score"] > 15000)]
a

# Display the student details --> whose codekata score "exceeds 15000 points"
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %%
a.to_csv('Exceeded_expectations.csv')

# Students who have CodeKata Score __more than 15000__ in "a" was stored into new csv file ---> "Exceeded_expectations.csv"

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
b = df[ (df["CodeKata Score"] >= 10000)  &  (df["CodeKata Score"] <= 15000) ]
b

# Display the student details --> whose codekata score in-between "10000 to 15000"
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        NaN
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      NaN
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %%
b.to_csv('Reached_expectations.csv')

# Students who have CodeKata Score __in-between 10000 to 15000__ in "b" was stored into new csv file ---> "Reached_expectations.csv"

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
c = df[ (df["CodeKata Score"] >= 7000)  &  (df["CodeKata Score"] <= 10000) ]
c

# Display the student details --> whose codekata score in-between "7000 to 10000"
# Out:
#                        Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4               Sathammai.S   100.0    8.0               8980            8980
# 5              NIVEESHWAR S   100.0    0.0               8200            8200
# 6             KALAIARASAN K    85.0   47.0               7750            7880
# 7      MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 88                VIINU V P    -1.0   24.0               9150            9150
# 89               Poojitha Y     0.0   35.0               7210            8970
# 90   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 91                Gowtham R    -1.0    4.0               8650            8650
# 92                 shifak N    58.0    0.0               5180            8320
# 93                  Balaji     -1.0   20.0               6170            8160
# 94                 Rushitha    -1.0   62.0               7470            8090
# ...

# %%
c.to_csv('Needs_Improvement.csv')

# Students who have CodeKata Score __in-between 7000 to 10000__ in "c" was stored into new csv file ---> "Needs_Improvement.csv"

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
d = df[ df["CodeKata Score"] < 7000 ]
d

# Display the student details --> whose codekata score "less than 7000"
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8         J.SUGANTHI    27.0  50.00               5860            5860
# 9       thamizhpaana    29.0   0.00               5500            5500
# 10   Iyappan Samiraj    50.0  24.00               5400            5400
# 11      Ponniyamma.R   100.0  11.25               5380            5380
# 12         SABAPATHI   100.0   0.00               5280            5280
# ..               ...     ...    ...                ...             ...
# 114    praveen raj j    24.0   0.00               2380            2380
# 115       AMARNATH D    -1.0  12.00               1890            1890
# 116             bala    32.0   0.00               1720            1720
# 117             XY Z    -1.0  -1.00                  0               0
# 118        Hariharan    -1.0  -1.00                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %%
d.to_csv('Unsatisfactory.csv')

# Students who have CodeKata Score _less than 7000_ in "d" was stored into new csv file ---> "Unsatisfactory.csv"

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
print( "Avg of Prev week geekions = {}".format(df["Previous Geekions"].mean()) )

# Displays mean value of Previous Geekions
# Out:
# Avg of Prev week geekions = 3842.3529411764707

# %%
print( "Avg of CodeKata Score = {}".format(df["CodeKata Score"].mean()) )

# Displays mean value of CodeKata Score
# Out:
# Avg of CodeKata Score = 4051.764705882353

# %%
"Avg of Prev week geekions vs Average of CodeKata Score = "+ str(df.Rising.mean() )
# Out:
# 'Avg of Prev week geekions vs Average of CodeKata Score = 209.41176470588235'

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### No of students participated

# %%
print( "Total No. of student participated = {}".format( len(df.Name.unique()) ))
# Out:
# Total No. of student participated = 119

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
Average = ['python','mysql','python_en','computational_thinking']

for i in Average:
    print("\n The Average of {} => {}".format(i,df[i].mean()))

# Displays Average value of all python, mysql, python_english, computational_thinking
# Out:
#  The Average of python => 54.35294117647059
#
#  The Average of mysql => 23.5
#
#  The Average of python_en => 29.65714285714286
#
#  The Average of computational_thinking => 2.2

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values(by = 'Rising', ascending = False).head(3)

# Displays Top - 3 candidates of particular week
# ascending = False ----> represents Descending Order
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 102        Computer Science and Engineering    2000       -1.0
# 86         Computer Science and Engineering    2000       55.0
#
#      computational_thinking
# 92                      0.0
# 102                     0.0
# 86                      6.0

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values(by = 'Previous Geekions', ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df.groupby(["Department"])["CodeKata Score"].sum()
# Out:
# Department
# Computer Science and Engineering             320025
# Electronics and Communication Engineering    108335
# Electronics and Electrical Engineering        53800
# Name: CodeKata Score, dtype: int64

# %%
w = list(df["Department"].unique())
plt.figure(figsize = (8,8))
explode = [0.05, 0.05, 0.04]
colors = ['cyan','grey','orange']
plt.pie(df.groupby(["Department"])["CodeKata Score"].sum(), labels=w, colors=colors, autopct='%1.1f%%', radius=0.8, shadow=False, data=True, explode=explode )
plt.title('---- Department-wise CODEKATA Performance ----')
plt.legend(bbox_to_anchor=(-0.6,0.6), loc='upper left')

# Displays Department wise codekata performence in form of "" ___PIE Chart*___"

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df.Department.unique()

# Displays "all departments name" which is present inside the df
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
EEE = df[df['Department']=='Electronics and Electrical Engineering'].sort_values('CodeKata Score', ascending=False).head(3)
CSE = df[df['Department']=='Computer Science and Engineering'].sort_values('CodeKata Score', ascending=False).head(3)
ECE = df[df['Department']=='Electronics and Communication Engineering'].sort_values('CodeKata Score', ascending=False).head(3)

highest = pd.concat([EEE, CSE, ECE], axis=0, ignore_index = True)
highest

# EEE -  Displays the EEE department topper details in Descending-order
# CSE -  Displays the CSE department topper details in Descending-order
# ECE -  Displays the ECE department topper details in Descending-order

# hhighest - Represent the concatination of all 3 department toppers
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    ASHOK KUMAR K   100.0   31.0              19400           19400
# 1        VIINU V P    -1.0   24.0               9150            9150
# 2         shifak N    58.0    0.0               5180            8320
# 3        A.Dharani    82.0   20.0              24500           24500
# 4      V.JEEVITHA     82.0   20.0              21740           21740
# 5      HEMAVATHI.R   100.0  100.0              19680           19680
# 6  Bodipudi Harini    -1.0   35.0              10040           10040
# 7        Gowtham R    -1.0    4.0               8650            8650
# 8    KALAIARASAN K    85.0   47.0               7750            7880
#
#                                   Department  Rising  python_en  \
# 0     Electronics and Electrical Engineering       0        0.0
# 1     Electronics and Electrical Engineering       0      100.0
# 2     Electronics and Electrical Engineering    3140        0.0
# ...

# %%
fig = px.bar(
    highest,
    x="Department",
    y=["Name", "CodeKata Score"],
    color='Name',
    barmode='group',
    title='Department wise Toppers'    
)

fig.update_layout(
    height=600,
    width=800,
    font_size=16,
    font_family ='Arial',
    legend_title_font_color='blue',
    title= dict(
        x=0.1,
        y=0.95,
        font= {
               "family":'Time New Roman',
               "size":28,
               "color":'black'
              }
    )
)
fig.show()


# Displays Department wise Topper in form of "___Bar-chart*___"
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#---------------------------------------------------------------------------- Thank you..! -------------------------------------------------------------------------------------------------
